# %%
import pandas as pd
import streamlit as st
import numpy as np

# %%
books_df = pd.read_csv('../data/books_clean.csv')
books_df
# Out:
#                                    Title               Author  Rating  \
# 0                              Gone Girl        Gillian Flynn    4.12
# 1                               The Help     Kathryn Stockett    4.47
# 2                  The Girl on the Train        Paula Hawkins    3.96
# 3                    The Handmaid’s Tale      Margaret Atwood    4.13
# 4      The Seven Husbands of Evelyn Hugo  Taylor Jenkins Reid    4.44
# ...                                  ...                  ...     ...
# 30639         The Fellowship of the Ring       J.R.R. Tolkien    4.38
# 30640                    Wires and Nerve        Marissa Meyer    4.12
# 30641                             Rumors       Anna Godbersen    3.85
# 30642                The Kingdom of Back             Marie Lu    3.70
# 30643                          Identical        Ellen Hopkins    4.30
#
#        Ratings count  Reviews count  Pages  First published  \
# 0            2911327         148502    415             2012
# 1            2627626          88917    464             2009
# 2            2767383         122845    336             2015
# 3            1918823          90689    314             1985
# 4            2326642         223037    389             2017
# ...              ...            ...    ...              ...
# 30639        2708740          35260    432             1954
# 30640          25977           4507    238             2017
# 30641          38906           1956    423             2008
# 30642          20006           4455    313             2020
# 30643          61477           3969    565             2008
#
#                                              Cover image          Genre  \
# 0      https://images-na.ssl-images-amazon.com/images...  Adult Fiction
# 1      https://images-na.ssl-images-amazon.com/images...  Adult Fiction
# 2      https://images-na.ssl-images-amazon.com/images...  Adult Fiction
# 3      https://images-na.ssl-images-amazon.com/images...  Adult Fiction
# 4      https://images-na.ssl-images-amazon.com/images...  Adult Fiction
# ...                                                  ...            ...
# 30639  https://images-na.ssl-images-amazon.com/images...    Young Adult
# 30640  https://images-na.ssl-images-amazon.com/images...    Young Adult
# 30641  https://images-na.ssl-images-amazon.com/images...    Young Adult
# 30642  https://images-na.ssl-images-amazon.com/images...    Young Adult
# 30643  https://images-na.ssl-images-amazon.com/images...    Young Adult
#
#                                                 Book url
# 0      https://www.goodreads.com/book/show/19288043-g...
# 1      https://www.goodreads.com/book/show/4667024-th...
# 2      https://www.goodreads.com/book/show/22557272-t...
# 3      https://www.goodreads.com/book/show/38447.The_...
# 4      https://www.goodreads.com/book/show/32620332-t...
# ...                                                  ...
# 30639  https://www.goodreads.com/book/show/61215351-t...
# 30640  https://www.goodreads.com/book/show/29772863-w...
# 30641  https://www.goodreads.com/book/show/2218252.Ru...
# 30642  https://www.goodreads.com/book/show/45872054-t...
# 30643  https://www.goodreads.com/book/show/2241059.Id...
#
# [30644 rows x 10 columns]

# %%
books_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30644 entries, 0 to 30643
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Title            30644 non-null  object
#  1   Author           30644 non-null  object
#  2   Rating           30644 non-null  float64
#  3   Ratings count    30644 non-null  int64
#  4   Reviews count    30644 non-null  int64
#  5   Pages            30644 non-null  int64
#  6   First published  30644 non-null  int64
#  7   Cover image      30644 non-null  object
#  8   Genre            30644 non-null  object
#  9   Book url         30644 non-null  object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 2.3+ MB

# %%
#Filter 1
genre = input('Which genre would you like to read?: ')
df_genre = books_df[books_df['Genre'] == genre]
# Out:
# Which genre would you like to read?: Fantasy

# %%
#Filter 2
pages = input('Would you like to read a short book or a long book?: ')
if pages == "short":
    df_pages = df_genre[df_genre['Pages'] <= 299]
else:
    df_pages = df_genre[df_genre['Pages'] >= 300]
# Out:
# Would you like to read a short book or a long book?: long

# %%
#filter 3
ratings_count = input('Would you like to read a popular book or a hidden gem?: ')
if ratings_count == "hidden gem":
    df_ratings_count = df_pages[df_pages['Ratings count'] <= 9999]
else:
    df_ratings_count = df_pages[df_pages['Ratings count'] >= 10000]
# Out:
# Would you like to read a popular book or a hidden gem?: popular

# %%
#filter 4
published = input('finally, do you prefer to read a recent book or a classic?: ')
if published == "classic":
    df_published = df_ratings_count[df_ratings_count['First published'] <= 2017]
else:
    df_published = df_ratings_count[df_ratings_count['First published'] >= 2018]
# Out:
# finally, do you prefer to read a recent book or a classic?: recent

# %%
df_published
# Out:
#                                   Title              Author  Rating  \
# 7915                   The Cruel Prince         Holly Black    4.07
# 7956  The Invisible Life of Addie LaRue         V.E. Schwab    4.21
# 7958                    The Wicked King         Holly Black    4.32
# 7960                              Circe     Madeline Miller    4.24
# 7963      The House in the Cerulean Sea          T.J. Klune    4.43
# ...                                 ...                 ...     ...
# 8863                            Skyward   Brandon Sanderson    4.49
# 8868            The Secret Commonwealth      Philip Pullman    4.04
# 8871                          Witchmark           C.L. Polk    3.87
# 8885           The Red Scrolls of Magic     Cassandra Clare    4.12
# 8886                  The Traitor Queen  Danielle L. Jensen    4.26
#
#       Ratings count  Reviews count  Pages  First published  \
# 7915         962877          88507    370             2018
# 7956         884388         116212    444             2020
# 7958         595092          57338    336             2019
# 7960         904506          89403    393             2018
# 7963         491573          81736    394             2020
# ...             ...            ...    ...              ...
# 8863         121465          16042    513             2018
# 8868          51225           5188    784             2019
# 8871          13214           2346    318             2018
# 8885          48449           6138    368             2019
# 8886          69578           6586    352             2020
#
#                                             Cover image    Genre  \
# 7915  https://images-na.ssl-images-amazon.com/images...  Fantasy
# 7956  https://images-na.ssl-images-amazon.com/images...  Fantasy
# 7958  https://images-na.ssl-images-amazon.com/images...  Fantasy
# 7960  https://images-na.ssl-images-amazon.com/images...  Fantasy
# 7963  https://images-na.ssl-images-amazon.com/images...  Fantasy
# ...                                                 ...      ...
# 8863  https://images-na.ssl-images-amazon.com/images...  Fantasy
# 8868  https://images-na.ssl-images-amazon.com/images...  Fantasy
# 8871  https://images-na.ssl-images-amazon.com/images...  Fantasy
# 8885  https://images-na.ssl-images-amazon.com/images...  Fantasy
# 8886  https://images-na.ssl-images-amazon.com/images...  Fantasy
#
#                                                Book url
# 7915  https://www.goodreads.com/book/show/26032825-t...
# 7956  https://www.goodreads.com/book/show/50623864-t...
# 7958  https://www.goodreads.com/book/show/26032887-t...
# 7960  https://www.goodreads.com/book/show/35959740-c...
# 7963  https://www.goodreads.com/book/show/45047384-t...
# ...                                                 ...
# 8863  https://www.goodreads.com/book/show/36642458-s...
# 8868  https://www.goodreads.com/book/show/19034943-t...
# 8871  https://www.goodreads.com/book/show/36187110-w...
# 8885  https://www.goodreads.com/book/show/30295312-t...
# 8886  https://www.goodreads.com/book/show/50719471-t...
#
# [165 rows x 10 columns]

# %%
df_sample = df_published[['Title', 'Author', 'Book url']].sample(n=6)
df_sample
# Out:
#                                           Title            Author  \
# 8518                            Sky in the Deep    Adrienne Young
# 8385                                  War Storm  Victoria Aveyard
# 8527                                   Vengeful       V.E. Schwab
# 8580  The Sword of Kaigen: A Theonite War Story         M.L. Wang
# 8171                   Once Upon a Broken Heart  Stephanie Garber
# 8359                                      Fable    Adrienne Young
#
#                                                Book url
# 8518  https://www.goodreads.com/book/show/34726469-s...
# 8385  https://www.goodreads.com/book/show/27188596-w...
# 8527  https://www.goodreads.com/book/show/26856502-v...
# 8580  https://www.goodreads.com/book/show/41886271-t...
# 8171  https://www.goodreads.com/book/show/55987278-o...
# 8359  https://www.goodreads.com/book/show/44012880-f...
